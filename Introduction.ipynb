# %%
x=3
y=4
z=x+y
print(z)
print("type(z)=",type(z))
i=float(z)
print("type(i)=",type(i))
# Out:
# 7
# type(z)= <class 'int'>
# type(i)= <class 'float'>

# %%
x=2.7
y=type(x)
print("y=",y)

h=4
print("h=",type(h))


print(type(4.9876))
# Out:
# y= <class 'float'>
# h= <class 'int'>
# <class 'float'>

# %%
x=3
y=5
n=x**y
nn=x*y
print(n)
print(nn)
# Out:
# 243
# 15

# %%
x=3
y=5

n=print(x*y)
d=print(x/y)
h=print(x+y)
m=print(x**y)
g=print(x%y)
g=print(x//y)
# Out:
# 15
# 0.6
# 8
# 243
# 3
# 0

# %%
x="Sobhani"
print(x)
# Out:
# Sobhani

# %%
x="Sobhani"
y="Dr."
z= y+x
print(z)

h=12
m=h+x
print(m)
# Out:
# Dr.Sobhani
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3304943111.py in <cell line: 0>()
#       5
#       6 h=12
# ----> 7 m=h+x
#       8 print(m)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x=2
y="Sobhani"
z=x*y
print(z)

print("WhatIsYourName=?")
# Out:
# SobhaniSobhani
# WhatIsYourName=?

# %%
x=2
y=5
z=x*y
print("x =",x,", y = ",y,", z =",z)
# Out:
# x = 2 , y =  5 , z = 10

# %%
x="125"
y=int(x)
print(type(x),type(y))

print(float(x))

f=2*y
print("f=",f)
# Out:
# <class 'str'> <class 'int'>
# 125.0
# f= 250

# %%
x=30
y=sin(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-9342705.py in <cell line: 0>()
#       1 x=30
# ----> 2 y=sin(x)
#       3 print(y)
#
# NameError: name 'sin' is not defined

# %%
import math
x=math.pi
print(x)


y=math.pi/2
z=math.sin(x)
print(z)
# Out:
# 3.141592653589793
# 1.2246467991473532e-16

# %%
import math
theta=90  #theta is versus degree
x=(theta/180)*math.pi # theta is changed to rad.
y=math.sin(x)
print(int(y))

print(dir(math))
# Out:
# 1
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
import math
x=-1
y=math.exp(x)
print(y)


a=20
b=4
y=math.pow(a,b)
print(y)
# Out:
# 0.36787944117144233
# 160000.0

# %%
import math
x=70
y=math.log(x,2)
print(y)
y1=math.log2(x)
print(y1)


Y=math.log(x,10)
print(Y)
Y1=math.log10(x)
print(Y1)

Y=math.log(x,10)
print(Y)
Y1=math.log10(x)
print(Y1)

xx=-4.5
yy=abs(xx)
print(yy)
yy1=math.fabs(x)
print(yy1)
# Out:
# 6.129283016944967
# 6.129283016944966
# 1.845098040014257
# 1.845098040014257
# 1.845098040014257
# 1.845098040014257
# 4.5
# 70.0

# %%
import math
x=2.3
y=math.floor(x)
print(y)
# Out:
# 2

# %%
import math  # First method
x=-1
y=math.sqrt(math.fabs(math.exp(x)))
print(y)


import math as h # Second method
x=-1
y=h.sqrt(h.fabs(h.exp(x)))
print(y)

from math import sqrt,fabs,exp # third method
x=-1
y=sqrt(fabs(exp(x)))
print(y)

from math import * # 4th method
x=+1
y=sqrt(fabs(exp(x))+3*log(x))
print(y)
# Out:
# 0.6065306597126334
# 0.6065306597126334
# 0.6065306597126334
# 1.6487212707001282

# %%
x=input("first Name=")        # code 1
y=input("last Name=")
print(x,y)

z=x+"        "+y              # code 2
print(z)
# Out:
# first Name=A
# last Name=B
# A B
# A        B

# %%
x=input("x=")          # code 1
y=input("y=")

z=float(x)+float(y)
print(z)

x=float(input("x="))          # code 2
y=float(input("y="))

z=x+y
print(z)
# Out:
# x=12
# y=15.5
# 27.5
# x=12
# y=25.5
# 37.5

# %%
Mkg=float(input("enter value in kg="))
Mg=Mkg*1000
print("Mg=",Mg)
# Out:
# enter value in kg=12.4
# Mg= 12400.0

# %%
name="NahidSobhanii"
print(name[0]) # index of the first character
print(name[1]) # index of the second character
print(name[1:8]) # index of the second to 7th character
print(name[:5])  #5: end index +1
print(name[1:6:2])
print(name[:])
print(name[::-1]) # inverse
print(name.index("a"))
print(name.upper())
print(name.lower())
print(name[-1])# index of the last character
print(len(name))# the number of character of a string
print(name.index("S"))
print(name.index("a"))
# Out:
# N
# a
# ahidSob
# Nahid
# aiS
# NahidSobhanii
# iinahboSdihaN
# 1
# NAHIDSOBHANII
# nahidsobhanii
# i
# 13
# 5
# 1

# %%
ClassName="Mitra Ali Hesam Mehri Sara Maryam Poya Ali"
ClassName=ClassName.replace("Mitra","Karami")
ClassName=ClassName.replace("Ali","Sharifi")
print(ClassName)
# Out:
# Karami Sharifi Hesam Mehri Sara Maryam Poya Sharifi

# %%
n="you are Physics students"
m=n.split()
print(m)

h=list(n)
print(h)
# Out:
# ['you', 'are', 'Physics', 'students']
# ['y', 'o', 'u', ' ', 'a', 'r', 'e', ' ', 'P', 'h', 'y', 's', 'i', 'c', 's', ' ', 's', 't', 'u', 'd', 'e', 'n', 't', 's']

# %%
P=input("Enter Password=")
n=len(P)
if n>8:
   print("It is fine.")
# Out:
# Enter Password=123478951
# It is fine.

# %%
P=input("Enter Password=")
n=len(P)
if n>8:
    print("It is fine.")
else:
    print("It isn't fine.")
# Out:
# Enter Password=45768123
# It isn't fine.

# %%
x=float(input("x="))
if x>12:
    print("*")
elif x>7:
    print("**")
elif x>2:
    print("***")
else:
    print("****")
    7.63
# Out:
# x=7.6
# **

# %%
x=float(input("x="))
if x>12:
    print("*")
if x>7:
    print("**")
if x>2:
    print("***")
else:
    print("****")
# Out:
# x=7.6
# **
# ***

# %%
import math
x=float(input("x="))
if x>10:
    y=math.log(x)
    print("ln(x)=",y)
elif 0<=x<=10:
    y=math.sqrt(x)
    print("sqrt(x)=",y)
elif x<0:
    y=math.exp(x)-1
    print("exp(x)-1=",y)
# Out:
# x=9.1
# sqrt(x)= 3.0166206257996713

# %%
name=input("first_name=")
if name[0]=="M" and name[-1]=="i":
    print("favorite name")
else:
    print("usual name")
# Out:
# first_name=Mary
# usual name
